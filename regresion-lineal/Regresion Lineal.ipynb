# %%
#cargan las librerias
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns
import pandas as pd
import numpy as np
import os
#llamamos el dataset
df = pd.read_csv('data.csv')
df
# Out:
#    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500

# %%
#se muestran algunos datos que son de utilidad
df.columns
df.info
df.describe
# Out:
# <bound method NDFrame.describe of    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500>

# %%
#Grafica de dispersion
df.plot.scatter(x='metro', y='precio')
plt.show()

# %%
#regresion lineal
regresion = linear_model.LinearRegression()

# %%
#se colocan los datos en un vector
metros = df['metro'].values.reshape((-1,1))

# %%
#se crea el modelo
modelo = regresion.fit(metros, df['precio'])

# %%
#imprime interseccion
print('Interseccion (b)', modelo.intercept_)
#imprime pendiente
print('pendiente (m)', modelo.coef_)
# Out:
# Interseccion (b) 361.25714285714287
# pendiente (m) [5.64571429]

# %%
#Definimos entradas y predicciones a utilizar en la grafica
entrada =[[5],[20],[25]]
predicciones = modelo.predict(entrada)
print(predicciones)
# Out:
# [389.48571429 474.17142857 502.4       ]

# %%
#imprimos las grafica
df.plot.scatter(x='metro', y='precio', label = 'Datos originales')
plt.scatter(entrada, predicciones, color='orange')
plt.plot(entrada, predicciones, color='black', label='Linea de Regresion')
plt.xlabel('metro')
plt.ylabel('precio')
plt.legend()
plt.show()
